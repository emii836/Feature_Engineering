# %%
from pathlib import Path
import pandas as pd
import  gc 
import numpy as np
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
import catboost
from catboost import datasets, CatBoostRegressor

# %%
p = Path.home() / 'AppData' / 'Local' / 'Packages' / \
...     'PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0' / \
...     'LocalCache' / 'local-packages' / 'Python39' / 'Scripts' / 'sample_train_numerai.csv'

train = pd.read_csv(p)

# %%
y=train["target"]
X=train.drop("target",axis=1)
X
# Out:
#     era data_type  feature_shaded_hallucinatory_dactylology  \
# 0     1     train                                         3
# 1     1     train                                         4
# 2     1     train                                         2
# 3     1     train                                         2
# 4     1     train                                         4
# ..  ...       ...                                       ...
# 95    1     train                                         0
# 96    1     train                                         2
# 97    1     train                                         3
# 98    1     train                                         2
# 99    1     train                                         3
#
#     feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                            4                             0
# 1                                            2                             4
# 2                                            4                             0
# 3                                            1                             3
# 4                                            1                             4
# ..                                         ...                           ...
# 95                                           1                             4
# 96                                           3                             3
# 97                                           1                             1
# 98                                           0                             2
# 99                                           4                             2
#
#     feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                       3                                   3
# 1                                       4                                   0
# 2                                       3                                   0
# 3                                       0                                   3
# 4                                       1                                   0
# ..                                    ...                                 ...
# 95                                      0                                   3
# 96                                      0                                   3
# 97                                      0                                   0
# 98                                      1                                   4
# 99                                      2                                   0
#
#     feature_symmetrical_spongy_tricentenary  \
# 0                                         1
# 1                                         0
# 2                                         3
# 3                                         0
# 4                                         4
# ..                                      ...
# 95                                        2
# 96                                        0
# 97                                        1
# 98                                        1
# 99                                        4
#
#     feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                        1                                0
# 1                                        4                                4
# 2                                        2                                4
# 3                                        3                                3
# 4                                        0                                4
# ..                                     ...                              ...
# 95                                       3                                2
# 96                                       1                                0
# 97                                       0                                3
# 98                                       2                                2
# 99                                       3                                4
#
#     ...  target_teager2b_20  target_teager2b_60  target_tyler_20  \
# 0   ...                0.50                0.50             0.25
# 1   ...                0.50                0.50             0.25
# 2   ...                1.00                1.00             1.00
# 3   ...                0.25                0.25             0.25
# 4   ...                0.50                0.50             0.25
# ..  ...                 ...                 ...              ...
# 95  ...                0.25                0.25             0.50
# 96  ...                0.50                0.25             0.50
# 97  ...                0.25                0.75             0.25
# 98  ...                0.50                0.75             0.50
# 99  ...                0.50                0.50             0.25
#
#     target_tyler_60  target_victor_20  target_victor_60  target_waldo_20  \
# 0              0.25              0.25              0.25             0.25
# 1              0.25              0.25              0.00             0.25
# 2              0.75              0.75              0.75             0.75
# 3              0.25              0.50              0.25             0.25
# 4              0.50              0.25              0.50             0.25
# ..              ...               ...               ...              ...
# 95             0.25              0.25              0.25             0.25
# 96             0.50              0.50              0.50             0.50
# 97             0.50              0.25              0.50             0.00
# 98             0.50              0.25              0.25             0.50
# 99             0.00              0.50              0.50             0.25
#
#     target_waldo_60  target_xerxes_20  target_xerxes_60
# 0              0.00              0.25              0.00
# 1              0.25              0.25              0.25
# 2              1.00              0.75              0.75
# 3              0.25              0.25              0.25
# 4              0.50              0.25              0.50
# ..              ...               ...               ...
# 95             0.25              0.25              0.50
# 96             0.25              0.50              0.50
# 97             0.75              0.25              0.75
# 98             0.50              0.50              0.75
# 99             0.25              0.25              0.50
#
# [100 rows x 2414 columns]

# %%
X=X.drop("era",axis=1)
X=X.drop("data_type",axis=1)
X
# Out:
#     feature_shaded_hallucinatory_dactylology  \
# 0                                          3
# 1                                          4
# 2                                          2
# 3                                          2
# 4                                          4
# ..                                       ...
# 95                                         0
# 96                                         2
# 97                                         3
# 98                                         2
# 99                                         3
#
#     feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                            4                             0
# 1                                            2                             4
# 2                                            4                             0
# 3                                            1                             3
# 4                                            1                             4
# ..                                         ...                           ...
# 95                                           1                             4
# 96                                           3                             3
# 97                                           1                             1
# 98                                           0                             2
# 99                                           4                             2
#
#     feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                       3                                   3
# 1                                       4                                   0
# 2                                       3                                   0
# 3                                       0                                   3
# 4                                       1                                   0
# ..                                    ...                                 ...
# 95                                      0                                   3
# 96                                      0                                   3
# 97                                      0                                   0
# 98                                      1                                   4
# 99                                      2                                   0
#
#     feature_symmetrical_spongy_tricentenary  \
# 0                                         1
# 1                                         0
# 2                                         3
# 3                                         0
# 4                                         4
# ..                                      ...
# 95                                        2
# 96                                        0
# 97                                        1
# 98                                        1
# 99                                        4
#
#     feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                        1                                0
# 1                                        4                                4
# 2                                        2                                4
# 3                                        3                                3
# 4                                        0                                4
# ..                                     ...                              ...
# 95                                       3                                2
# 96                                       1                                0
# 97                                       0                                3
# 98                                       2                                2
# 99                                       3                                4
#
#     feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  \
# 0                                     0                                 0
# 1                                     3                                 0
# 2                                     2                                 2
# 3                                     4                                 2
# 4                                     4                                 0
# ..                                  ...                               ...
# 95                                    4                                 1
# 96                                    2                                 3
# 97                                    1                                 2
# 98                                    1                                 2
# 99                                    2                                 3
#
#     ...  target_teager2b_20  target_teager2b_60  target_tyler_20  \
# 0   ...                0.50                0.50             0.25
# 1   ...                0.50                0.50             0.25
# 2   ...                1.00                1.00             1.00
# 3   ...                0.25                0.25             0.25
# 4   ...                0.50                0.50             0.25
# ..  ...                 ...                 ...              ...
# 95  ...                0.25                0.25             0.50
# 96  ...                0.50                0.25             0.50
# 97  ...                0.25                0.75             0.25
# 98  ...                0.50                0.75             0.50
# 99  ...                0.50                0.50             0.25
#
#     target_tyler_60  target_victor_20  target_victor_60  target_waldo_20  \
# 0              0.25              0.25              0.25             0.25
# 1              0.25              0.25              0.00             0.25
# 2              0.75              0.75              0.75             0.75
# 3              0.25              0.50              0.25             0.25
# 4              0.50              0.25              0.50             0.25
# ..              ...               ...               ...              ...
# 95             0.25              0.25              0.25             0.25
# 96             0.50              0.50              0.50             0.50
# 97             0.50              0.25              0.50             0.00
# 98             0.50              0.25              0.25             0.50
# 99             0.00              0.50              0.50             0.25
#
#     target_waldo_60  target_xerxes_20  target_xerxes_60
# 0              0.00              0.25              0.00
# 1              0.25              0.25              0.25
# 2              1.00              0.75              0.75
# 3              0.25              0.25              0.25
# 4              0.50              0.25              0.50
# ..              ...               ...               ...
# 95             0.25              0.25              0.50
# 96             0.25              0.50              0.50
# 97             0.75              0.25              0.75
# 98             0.50              0.50              0.75
# 99             0.25              0.25              0.50
#
# [100 rows x 2412 columns]

# %%
good_cols=[col for col in X.columns if not col.startswith("target")]
 
X=X[good_cols]
X
# Out:
#     feature_shaded_hallucinatory_dactylology  \
# 0                                          3
# 1                                          4
# 2                                          2
# 3                                          2
# 4                                          4
# ..                                       ...
# 95                                         0
# 96                                         2
# 97                                         3
# 98                                         2
# 99                                         3
#
#     feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                            4                             0
# 1                                            2                             4
# 2                                            4                             0
# 3                                            1                             3
# 4                                            1                             4
# ..                                         ...                           ...
# 95                                           1                             4
# 96                                           3                             3
# 97                                           1                             1
# 98                                           0                             2
# 99                                           4                             2
#
#     feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                       3                                   3
# 1                                       4                                   0
# 2                                       3                                   0
# 3                                       0                                   3
# 4                                       1                                   0
# ..                                    ...                                 ...
# 95                                      0                                   3
# 96                                      0                                   3
# 97                                      0                                   0
# 98                                      1                                   4
# 99                                      2                                   0
#
#     feature_symmetrical_spongy_tricentenary  \
# 0                                         1
# 1                                         0
# 2                                         3
# 3                                         0
# 4                                         4
# ..                                      ...
# 95                                        2
# 96                                        0
# 97                                        1
# 98                                        1
# 99                                        4
#
#     feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                        1                                0
# 1                                        4                                4
# 2                                        2                                4
# 3                                        3                                3
# 4                                        0                                4
# ..                                     ...                              ...
# 95                                       3                                2
# 96                                       1                                0
# 97                                       0                                3
# 98                                       2                                2
# 99                                       3                                4
#
#     feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  \
# 0                                     0                                 0
# 1                                     3                                 0
# 2                                     2                                 2
# 3                                     4                                 2
# 4                                     4                                 0
# ..                                  ...                               ...
# 95                                    4                                 1
# 96                                    2                                 3
# 97                                    1                                 2
# 98                                    1                                 2
# 99                                    2                                 3
#
#     ...  feature_sprucer_godlier_assembling  \
# 0   ...                                   2
# 1   ...                                   2
# 2   ...                                   2
# 3   ...                                   2
# 4   ...                                   2
# ..  ...                                 ...
# 95  ...                                   2
# 96  ...                                   2
# 97  ...                                   2
# 98  ...                                   2
# 99  ...                                   2
#
#     feature_venturesome_jesting_characterisation  \
# 0                                              2
# 1                                              2
# 2                                              2
# 3                                              2
# 4                                              2
# ..                                           ...
# 95                                             2
# 96                                             2
# 97                                             2
# 98                                             2
# 99                                             2
#
#     feature_unstained_anhedonic_hetty  \
# 0                                   2
# 1                                   2
# 2                                   2
# 3                                   2
# 4                                   2
# ..                                ...
# 95                                  2
# 96                                  2
# 97                                  2
# 98                                  2
# 99                                  2
#
#     feature_vivisectional_latvian_dispensator  \
# 0                                           2
# 1                                           2
# 2                                           2
# 3                                           2
# 4                                           2
# ..                                        ...
# 95                                          2
# 96                                          2
# 97                                          2
# 98                                          2
# 99                                          2
#
#     feature_pantheist_interramal_episcopalianism  \
# 0                                              2
# 1                                              2
# 2                                              2
# 3                                              2
# 4                                              2
# ..                                           ...
# 95                                             2
# 96                                             2
# 97                                             2
# 98                                             2
# 99                                             2
#
#     feature_percurrent_deontic_sectionalisation  \
# 0                                             2
# 1                                             2
# 2                                             2
# 3                                             2
# 4                                             2
# ..                                          ...
# 95                                            2
# 96                                            2
# 97                                            2
# 98                                            2
# 99                                            2
#
#     feature_myalgic_eulogistic_propagation  \
# 0                                        2
# 1                                        2
# 2                                        2
# 3                                        2
# 4                                        2
# ..                                     ...
# 95                                       2
# 96                                       2
# 97                                       2
# 98                                       2
# 99                                       2
#
#     feature_pressor_chiropodial_hypertension  feature_diogenic_wooden_lout  \
# 0                                          2                             2
# 1                                          2                             2
# 2                                          2                             2
# 3                                          2                             2
# 4                                          2                             2
# ..                                       ...                           ...
# 95                                         2                             2
# 96                                         2                             2
# 97                                         2                             2
# 98                                         2                             2
# 99                                         2                             2
#
#     feature_pleuritic_equipotent_loudmouth
# 0                                        2
# 1                                        2
# 2                                        2
# 3                                        2
# 4                                        2
# ..                                     ...
# 95                                       2
# 96                                       2
# 97                                       2
# 98                                       2
# 99                                       2
#
# [100 rows x 2376 columns]

# %%
X=X.reset_index(drop=True)
y=y.reset_index(drop=True)

# %%
X.isnull().values.any()
# Out:
# np.False_

# %%
def  kin_energy(x):
    f=np.unique(x,return_counts=True)
    prob=f[1]/x.shape[0]
    energy=np.sum(prob**2)
    return  energy

# %%
def count_common(x):
    a=np.array(x)
    b=np.where(a==np.min(a))
    v=np.array(b)
    nr_ap=v.shape[1]
    return nr_ap

# %%
def count_least(x):
    a=np.array(x)
    b=np.where(a==np.max(a))
    v=np.array(b)
    nr_ap=v.shape[1]
    return nr_ap

# %%
X["KINETIC_FEAT"]=X.apply(kin_energy,axis=1)
X["mean_FEAT"]=X[good_cols].apply(np.mean,axis=1)
X["COMMON_COUNT_FEAT"]=X.apply(count_common,axis=1)
X["LEAST_COUNT_FEAT"]=X.apply(count_least,axis=1)

# %%
del train
gc.collect()
# Out:
# 0

# %%
X["KINETIC_FEAT"]=np.round(X["KINETIC_FEAT"], decimals=2)
X["mean_FEAT"]=np.round(X["mean_FEAT"], decimals=2)

# %%
X["KINETIC_FEAT"]=( X["KINETIC_FEAT"]% 1 * 100).astype(int)
X["mean_FEAT"]=( X["mean_FEAT"]% 1 * 100).astype(int)

# %%
train=X

# %%
train.head()
# Out:
#    feature_shaded_hallucinatory_dactylology  \
# 0                                         3
# 1                                         4
# 2                                         2
# 3                                         2
# 4                                         4
#
#    feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                           4                             0
# 1                                           2                             4
# 2                                           4                             0
# 3                                           1                             3
# 4                                           1                             4
#
#    feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                      3                                   3
# 1                                      4                                   0
# 2                                      3                                   0
# 3                                      0                                   3
# 4                                      1                                   0
#
#    feature_symmetrical_spongy_tricentenary  \
# 0                                        1
# 1                                        0
# 2                                        3
# 3                                        0
# 4                                        4
#
#    feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                       1                                0
# 1                                       4                                4
# 2                                       2                                4
# 3                                       3                                3
# 4                                       0                                4
#
#    feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  ...  \
# 0                                    0                                 0  ...
# 1                                    3                                 0  ...
# 2                                    2                                 2  ...
# 3                                    4                                 2  ...
# 4                                    4                                 0  ...
#
#    feature_pantheist_interramal_episcopalianism  \
# 0                                             2
# 1                                             2
# 2                                             2
# 3                                             2
# 4                                             2
#
#    feature_percurrent_deontic_sectionalisation  \
# 0                                            2
# 1                                            2
# 2                                            2
# 3                                            2
# 4                                            2
#
#    feature_myalgic_eulogistic_propagation  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3                                       2
# 4                                       2
#
#    feature_pressor_chiropodial_hypertension  feature_diogenic_wooden_lout  \
# 0                                         2                             2
# 1                                         2                             2
# 2                                         2                             2
# 3                                         2                             2
# 4                                         2                             2
#
#    feature_pleuritic_equipotent_loudmouth  KINETIC_FEAT  mean_FEAT  \
# 0                                       2            40          0
# 1                                       2            39         95
# 2                                       2            43         96
# 3                                       2            40          0
# 4                                       2            38          2
#
#    COMMON_COUNT_FEAT  LEAST_COUNT_FEAT
# 0                182                 1
# 1                400                 1
# 2                167                 1
# 3                203                 1
# 4                221                 1
#
# [5 rows x 2380 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

# %%
params = {
        "n_estimators": 3_000,
        "learning_rate": 0.05,
        "max_depth": 5,
        #"colsample_bylevel": 0.1,
       
    }
# print out training values 10 times during training run
params["verbose"] = int(params["n_estimators"]/10)
    # max_leaves is left to default value of 31 as it recommended not to make it larger than 64
    
model = CatBoostRegressor(**params)

# %%
model.fit(X_train, y_train)
# Out:
# 0:	learn: 0.2423633	total: 205ms	remaining: 10m 14s
# 300:	learn: 0.0028510	total: 7.83s	remaining: 1m 10s
# 600:	learn: 0.0000401	total: 15.5s	remaining: 1m 2s
# 900:	learn: 0.0000009	total: 23.2s	remaining: 54.1s
# 1200:	learn: 0.0000000	total: 30.7s	remaining: 46s
# 1500:	learn: 0.0000000	total: 38.2s	remaining: 38.2s
# 1800:	learn: 0.0000000	total: 45.9s	remaining: 30.5s
# 2100:	learn: 0.0000000	total: 53.5s	remaining: 22.9s
# 2400:	learn: 0.0000000	total: 1m 1s	remaining: 15.3s
# 2700:	learn: 0.0000000	total: 1m 8s	remaining: 7.62s
# 2999:	learn: 0.0000000	total: 1m 16s	remaining: 0us

# %%
feature_importances = model.get_feature_importance()

# Get feature names (assuming 'model.feature_names_' contains the feature names)
feature_names = model.feature_names_

# Combine feature names and importance scores into a DataFrame
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances
})

# Sort the DataFrame by importance scores in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
feature_importances
# Out:
# array([3.80522744e-09, 4.67340200e-02, 2.49639225e-19, ...,
#        1.19433755e-01, 1.96913572e-01, 0.00000000e+00])

# %%
np.corrcoef(X["feature_elusive_vapoury_accomplice"], X["feature_approbatory_labroid_coracle"])
# Out:
# array([[ 1.        , -0.06994773],
#        [-0.06994773,  1.        ]])

# %%
def gcd(a, b):
    if a == 0 or b == 0:
        return max(a, b)
    return gcd(b, a % b)

# %%
X["GCD_FEAT"]=X.apply(lambda r: gcd(r["feature_elusive_vapoury_accomplice"],r["feature_fortified_repressed_baird"]),axis=1)

# %%
def l(a, b):
    if a==0 or b==0:
        return max(a, b)
    else:
        if a!=0 and b!=0:
           lcm=(a*b)/gcd(a, b)
    if a==0 and b==0:
        return 0
    return lcm

# %%
X["LCM_FEAT"]=X.apply(lambda r: l(r["feature_elusive_vapoury_accomplice"], r["feature_limiest_heliolithic_york"]),axis=1)

# %%
train.head()
# Out:
#    feature_shaded_hallucinatory_dactylology  \
# 0                                         3
# 1                                         4
# 2                                         2
# 3                                         2
# 4                                         4
#
#    feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                           4                             0
# 1                                           2                             4
# 2                                           4                             0
# 3                                           1                             3
# 4                                           1                             4
#
#    feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                      3                                   3
# 1                                      4                                   0
# 2                                      3                                   0
# 3                                      0                                   3
# 4                                      1                                   0
#
#    feature_symmetrical_spongy_tricentenary  \
# 0                                        1
# 1                                        0
# 2                                        3
# 3                                        0
# 4                                        4
#
#    feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                       1                                0
# 1                                       4                                4
# 2                                       2                                4
# 3                                       3                                3
# 4                                       0                                4
#
#    feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  ...  \
# 0                                    0                                 0  ...
# 1                                    3                                 0  ...
# 2                                    2                                 2  ...
# 3                                    4                                 2  ...
# 4                                    4                                 0  ...
#
#    feature_myalgic_eulogistic_propagation  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3                                       2
# 4                                       2
#
#    feature_pressor_chiropodial_hypertension  feature_diogenic_wooden_lout  \
# 0                                         2                             2
# 1                                         2                             2
# 2                                         2                             2
# 3                                         2                             2
# 4                                         2                             2
#
#    feature_pleuritic_equipotent_loudmouth  KINETIC_FEAT  mean_FEAT  \
# 0                                       2            40          0
# 1                                       2            39         95
# 2                                       2            43         96
# 3                                       2            40          0
# 4                                       2            38          2
#
#    COMMON_COUNT_FEAT  LEAST_COUNT_FEAT  GCD_FEAT  LCM_FEAT
# 0                182                 1         1       1.0
# 1                400                 1         4       4.0
# 2                167                 1         3       2.0
# 3                203                 1         1       6.0
# 4                221                 1         1       2.0
#
# [5 rows x 2382 columns]

# %%
X["LCM_FEAT"]=X["LCM_FEAT"].astype(int)

# %%
X.head()
# Out:
#    feature_shaded_hallucinatory_dactylology  \
# 0                                         3
# 1                                         4
# 2                                         2
# 3                                         2
# 4                                         4
#
#    feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                           4                             0
# 1                                           2                             4
# 2                                           4                             0
# 3                                           1                             3
# 4                                           1                             4
#
#    feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                      3                                   3
# 1                                      4                                   0
# 2                                      3                                   0
# 3                                      0                                   3
# 4                                      1                                   0
#
#    feature_symmetrical_spongy_tricentenary  \
# 0                                        1
# 1                                        0
# 2                                        3
# 3                                        0
# 4                                        4
#
#    feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                       1                                0
# 1                                       4                                4
# 2                                       2                                4
# 3                                       3                                3
# 4                                       0                                4
#
#    feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  ...  \
# 0                                    0                                 0  ...
# 1                                    3                                 0  ...
# 2                                    2                                 2  ...
# 3                                    4                                 2  ...
# 4                                    4                                 0  ...
#
#    feature_myalgic_eulogistic_propagation  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3                                       2
# 4                                       2
#
#    feature_pressor_chiropodial_hypertension  feature_diogenic_wooden_lout  \
# 0                                         2                             2
# 1                                         2                             2
# 2                                         2                             2
# 3                                         2                             2
# 4                                         2                             2
#
#    feature_pleuritic_equipotent_loudmouth  KINETIC_FEAT  mean_FEAT  \
# 0                                       2            40          0
# 1                                       2            39         95
# 2                                       2            43         96
# 3                                       2            40          0
# 4                                       2            38          2
#
#    COMMON_COUNT_FEAT  LEAST_COUNT_FEAT  GCD_FEAT  LCM_FEAT
# 0                182                 1         1         1
# 1                400                 1         4         4
# 2                167                 1         3         2
# 3                203                 1         1         6
# 4                221                 1         1         2
#
# [5 rows x 2382 columns]

# %%
def sum_q(l, r, x):
    a=np.array(x)
    n=len(a)
    if l>r:
        aux=l
        l=r
        r=aux
    if r==l:
        s=a[0]
    if n>r and  n>l:
            s=sum(a[i] for i in range(l, r))
  
            return s

# %%
x=[1, -1, 7, 2, -3, -2, 4]
print (sum_q(1, 4, x))
print (sum_q(2, 6, x))
# Out:
# 8
# 4

# %%
np.corrcoef(X["GCD_FEAT"], X["LCM_FEAT"])
# Out:
# array([[1.        , 0.17254718],
#        [0.17254718, 1.        ]])

# %%
X["SUM_QUERY_FEAT"]=X.apply(lambda r: sum_q(r["GCD_FEAT"], r["LCM_FEAT"], r),axis=1)

# %%
train.head(20)
# Out:
#     feature_shaded_hallucinatory_dactylology  \
# 0                                          3
# 1                                          4
# 2                                          2
# 3                                          2
# 4                                          4
# 5                                          4
# 6                                          1
# 7                                          4
# 8                                          3
# 9                                          0
# 10                                         4
# 11                                         0
# 12                                         4
# 13                                         1
# 14                                         1
# 15                                         0
# 16                                         4
# 17                                         2
# 18                                         4
# 19                                         0
#
#     feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                            4                             0
# 1                                            2                             4
# 2                                            4                             0
# 3                                            1                             3
# 4                                            1                             4
# 5                                            2                             2
# 6                                            3                             1
# 7                                            4                             4
# 8                                            1                             3
# 9                                            3                             0
# 10                                           0                             0
# 11                                           2                             3
# 12                                           0                             1
# 13                                           1                             1
# 14                                           0                             1
# 15                                           4                             3
# 16                                           2                             4
# 17                                           3                             0
# 18                                           1                             4
# 19                                           0                             2
#
#     feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                       3                                   3
# 1                                       4                                   0
# 2                                       3                                   0
# 3                                       0                                   3
# 4                                       1                                   0
# 5                                       3                                   0
# 6                                       2                                   1
# 7                                       4                                   0
# 8                                       0                                   1
# 9                                       3                                   4
# 10                                      4                                   4
# 11                                      1                                   4
# 12                                      0                                   2
# 13                                      2                                   3
# 14                                      0                                   4
# 15                                      4                                   2
# 16                                      2                                   2
# 17                                      1                                   1
# 18                                      4                                   2
# 19                                      3                                   4
#
#     feature_symmetrical_spongy_tricentenary  \
# 0                                         1
# 1                                         0
# 2                                         3
# 3                                         0
# 4                                         4
# 5                                         4
# 6                                         4
# 7                                         0
# 8                                         1
# 9                                         4
# 10                                        0
# 11                                        0
# 12                                        4
# 13                                        0
# 14                                        0
# 15                                        1
# 16                                        3
# 17                                        0
# 18                                        4
# 19                                        1
#
#     feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                        1                                0
# 1                                        4                                4
# 2                                        2                                4
# 3                                        3                                3
# 4                                        0                                4
# 5                                        1                                4
# 6                                        1                                1
# 7                                        4                                2
# 8                                        2                                4
# 9                                        1                                1
# 10                                       0                                0
# 11                                       4                                4
# 12                                       2                                4
# 13                                       0                                1
# 14                                       4                                1
# 15                                       4                                2
# 16                                       1                                0
# 17                                       2                                4
# 18                                       4                                1
# 19                                       0                                0
#
#     feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  \
# 0                                     0                                 0
# 1                                     3                                 0
# 2                                     2                                 2
# 3                                     4                                 2
# 4                                     4                                 0
# 5                                     1                                 3
# 6                                     3                                 3
# 7                                     3                                 0
# 8                                     1                                 0
# 9                                     0                                 2
# 10                                    2                                 0
# 11                                    0                                 1
# 12                                    3                                 2
# 13                                    4                                 3
# 14                                    2                                 2
# 15                                    0                                 2
# 16                                    4                                 2
# 17                                    1                                 3
# 18                                    3                                 4
# 19                                    3                                 4
#
#     ...  feature_pressor_chiropodial_hypertension  \
# 0   ...                                         2
# 1   ...                                         2
# 2   ...                                         2
# 3   ...                                         2
# 4   ...                                         2
# 5   ...                                         2
# 6   ...                                         2
# 7   ...                                         2
# 8   ...                                         2
# 9   ...                                         2
# 10  ...                                         2
# 11  ...                                         2
# 12  ...                                         2
# 13  ...                                         2
# 14  ...                                         2
# 15  ...                                         2
# 16  ...                                         2
# 17  ...                                         2
# 18  ...                                         2
# 19  ...                                         2
#
#     feature_diogenic_wooden_lout  feature_pleuritic_equipotent_loudmouth  \
# 0                              2                                       2
# 1                              2                                       2
# 2                              2                                       2
# 3                              2                                       2
# 4                              2                                       2
# 5                              2                                       2
# 6                              2                                       2
# 7                              2                                       2
# 8                              2                                       2
# 9                              2                                       2
# 10                             2                                       2
# 11                             2                                       2
# 12                             2                                       2
# 13                             2                                       2
# 14                             2                                       2
# 15                             2                                       2
# 16                             2                                       2
# 17                             2                                       2
# 18                             2                                       2
# 19                             2                                       2
#
#     KINETIC_FEAT  mean_FEAT  COMMON_COUNT_FEAT  LEAST_COUNT_FEAT  GCD_FEAT  \
# 0             40          0                182                 1         1
# 1             39         95                400                 1         4
# 2             43         96                167                 1         3
# 3             40          0                203                 1         1
# 4             38          2                221                 1         1
# 5             45         85                308                 1         1
# 6             44         16                108                 1         4
# 7             37         94                287                 1         3
# 8             39         84                407                 1         2
# 9             40          6                202                 1         3
# 10            38         77                452                 1         1
# 11            41         90                282                 1         2
# 12            39         86                290                 1         1
# 13            44         98                186                 1         1
# 14            42         98                190                 1         1
# 15            38         25                152                 1         1
# 16            42         89                340                 1         2
# 17            41          0                131                 1         2
# 18            43          8                189                 1         3
# 19            42         16                130                 1         1
#
#     LCM_FEAT  SUM_QUERY_FEAT
# 0          1               0
# 1          4               0
# 2          2               0
# 3          6               7
# 4          2               1
# 5          0               4
# 6          4               0
# 7          3               0
# 8          2               0
# 9          3               0
# 10         4               4
# 11         2               0
# 12         1               0
# 13         3               2
# 14         3               1
# 15         3               7
# 16         4               6
# 17         4               1
# 18        12              22
# 19         4               5
#
# [20 rows x 2383 columns]
