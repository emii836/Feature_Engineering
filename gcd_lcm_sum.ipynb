# %%
from pathlib import Path
import pandas as pd
import  gc 
import numpy as np
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier
import catboost
from catboost import datasets, CatBoostRegressor
import math

# %%
p = Path.home() / 'AppData' / 'Local' / 'Packages' / \
...     'PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0' / \
...     'LocalCache' / 'local-packages' / 'Python39' / 'Scripts' / 'sample_train_numerai.csv'

train = pd.read_csv(p)

# %%
y=train["target"]
X=train.drop("target",axis=1)
X
# Out:
#     era data_type  feature_shaded_hallucinatory_dactylology  \
# 0     1     train                                         3
# 1     1     train                                         4
# 2     1     train                                         2
# 3     1     train                                         2
# 4     1     train                                         4
# ..  ...       ...                                       ...
# 95    1     train                                         0
# 96    1     train                                         2
# 97    1     train                                         3
# 98    1     train                                         2
# 99    1     train                                         3
#
#     feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                            4                             0
# 1                                            2                             4
# 2                                            4                             0
# 3                                            1                             3
# 4                                            1                             4
# ..                                         ...                           ...
# 95                                           1                             4
# 96                                           3                             3
# 97                                           1                             1
# 98                                           0                             2
# 99                                           4                             2
#
#     feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                       3                                   3
# 1                                       4                                   0
# 2                                       3                                   0
# 3                                       0                                   3
# 4                                       1                                   0
# ..                                    ...                                 ...
# 95                                      0                                   3
# 96                                      0                                   3
# 97                                      0                                   0
# 98                                      1                                   4
# 99                                      2                                   0
#
#     feature_symmetrical_spongy_tricentenary  \
# 0                                         1
# 1                                         0
# 2                                         3
# 3                                         0
# 4                                         4
# ..                                      ...
# 95                                        2
# 96                                        0
# 97                                        1
# 98                                        1
# 99                                        4
#
#     feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                        1                                0
# 1                                        4                                4
# 2                                        2                                4
# 3                                        3                                3
# 4                                        0                                4
# ..                                     ...                              ...
# 95                                       3                                2
# 96                                       1                                0
# 97                                       0                                3
# 98                                       2                                2
# 99                                       3                                4
#
#     ...  target_teager2b_20  target_teager2b_60  target_tyler_20  \
# 0   ...                0.50                0.50             0.25
# 1   ...                0.50                0.50             0.25
# 2   ...                1.00                1.00             1.00
# 3   ...                0.25                0.25             0.25
# 4   ...                0.50                0.50             0.25
# ..  ...                 ...                 ...              ...
# 95  ...                0.25                0.25             0.50
# 96  ...                0.50                0.25             0.50
# 97  ...                0.25                0.75             0.25
# 98  ...                0.50                0.75             0.50
# 99  ...                0.50                0.50             0.25
#
#     target_tyler_60  target_victor_20  target_victor_60  target_waldo_20  \
# 0              0.25              0.25              0.25             0.25
# 1              0.25              0.25              0.00             0.25
# 2              0.75              0.75              0.75             0.75
# 3              0.25              0.50              0.25             0.25
# 4              0.50              0.25              0.50             0.25
# ..              ...               ...               ...              ...
# 95             0.25              0.25              0.25             0.25
# 96             0.50              0.50              0.50             0.50
# 97             0.50              0.25              0.50             0.00
# 98             0.50              0.25              0.25             0.50
# 99             0.00              0.50              0.50             0.25
#
#     target_waldo_60  target_xerxes_20  target_xerxes_60
# 0              0.00              0.25              0.00
# 1              0.25              0.25              0.25
# 2              1.00              0.75              0.75
# 3              0.25              0.25              0.25
# 4              0.50              0.25              0.50
# ..              ...               ...               ...
# 95             0.25              0.25              0.50
# 96             0.25              0.50              0.50
# 97             0.75              0.25              0.75
# 98             0.50              0.50              0.75
# 99             0.25              0.25              0.50
#
# [100 rows x 2414 columns]

# %%
X=X.drop("era",axis=1)
X=X.drop("data_type",axis=1)
X
# Out:
#     feature_shaded_hallucinatory_dactylology  \
# 0                                          3
# 1                                          4
# 2                                          2
# 3                                          2
# 4                                          4
# ..                                       ...
# 95                                         0
# 96                                         2
# 97                                         3
# 98                                         2
# 99                                         3
#
#     feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                            4                             0
# 1                                            2                             4
# 2                                            4                             0
# 3                                            1                             3
# 4                                            1                             4
# ..                                         ...                           ...
# 95                                           1                             4
# 96                                           3                             3
# 97                                           1                             1
# 98                                           0                             2
# 99                                           4                             2
#
#     feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                       3                                   3
# 1                                       4                                   0
# 2                                       3                                   0
# 3                                       0                                   3
# 4                                       1                                   0
# ..                                    ...                                 ...
# 95                                      0                                   3
# 96                                      0                                   3
# 97                                      0                                   0
# 98                                      1                                   4
# 99                                      2                                   0
#
#     feature_symmetrical_spongy_tricentenary  \
# 0                                         1
# 1                                         0
# 2                                         3
# 3                                         0
# 4                                         4
# ..                                      ...
# 95                                        2
# 96                                        0
# 97                                        1
# 98                                        1
# 99                                        4
#
#     feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                        1                                0
# 1                                        4                                4
# 2                                        2                                4
# 3                                        3                                3
# 4                                        0                                4
# ..                                     ...                              ...
# 95                                       3                                2
# 96                                       1                                0
# 97                                       0                                3
# 98                                       2                                2
# 99                                       3                                4
#
#     feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  \
# 0                                     0                                 0
# 1                                     3                                 0
# 2                                     2                                 2
# 3                                     4                                 2
# 4                                     4                                 0
# ..                                  ...                               ...
# 95                                    4                                 1
# 96                                    2                                 3
# 97                                    1                                 2
# 98                                    1                                 2
# 99                                    2                                 3
#
#     ...  target_teager2b_20  target_teager2b_60  target_tyler_20  \
# 0   ...                0.50                0.50             0.25
# 1   ...                0.50                0.50             0.25
# 2   ...                1.00                1.00             1.00
# 3   ...                0.25                0.25             0.25
# 4   ...                0.50                0.50             0.25
# ..  ...                 ...                 ...              ...
# 95  ...                0.25                0.25             0.50
# 96  ...                0.50                0.25             0.50
# 97  ...                0.25                0.75             0.25
# 98  ...                0.50                0.75             0.50
# 99  ...                0.50                0.50             0.25
#
#     target_tyler_60  target_victor_20  target_victor_60  target_waldo_20  \
# 0              0.25              0.25              0.25             0.25
# 1              0.25              0.25              0.00             0.25
# 2              0.75              0.75              0.75             0.75
# 3              0.25              0.50              0.25             0.25
# 4              0.50              0.25              0.50             0.25
# ..              ...               ...               ...              ...
# 95             0.25              0.25              0.25             0.25
# 96             0.50              0.50              0.50             0.50
# 97             0.50              0.25              0.50             0.00
# 98             0.50              0.25              0.25             0.50
# 99             0.00              0.50              0.50             0.25
#
#     target_waldo_60  target_xerxes_20  target_xerxes_60
# 0              0.00              0.25              0.00
# 1              0.25              0.25              0.25
# 2              1.00              0.75              0.75
# 3              0.25              0.25              0.25
# 4              0.50              0.25              0.50
# ..              ...               ...               ...
# 95             0.25              0.25              0.50
# 96             0.25              0.50              0.50
# 97             0.75              0.25              0.75
# 98             0.50              0.50              0.75
# 99             0.25              0.25              0.50
#
# [100 rows x 2412 columns]

# %%
good_cols=[col for col in X.columns if not col.startswith("target")]
 
X=X[good_cols]
X
# Out:
#     feature_shaded_hallucinatory_dactylology  \
# 0                                          3
# 1                                          4
# 2                                          2
# 3                                          2
# 4                                          4
# ..                                       ...
# 95                                         0
# 96                                         2
# 97                                         3
# 98                                         2
# 99                                         3
#
#     feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                            4                             0
# 1                                            2                             4
# 2                                            4                             0
# 3                                            1                             3
# 4                                            1                             4
# ..                                         ...                           ...
# 95                                           1                             4
# 96                                           3                             3
# 97                                           1                             1
# 98                                           0                             2
# 99                                           4                             2
#
#     feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                       3                                   3
# 1                                       4                                   0
# 2                                       3                                   0
# 3                                       0                                   3
# 4                                       1                                   0
# ..                                    ...                                 ...
# 95                                      0                                   3
# 96                                      0                                   3
# 97                                      0                                   0
# 98                                      1                                   4
# 99                                      2                                   0
#
#     feature_symmetrical_spongy_tricentenary  \
# 0                                         1
# 1                                         0
# 2                                         3
# 3                                         0
# 4                                         4
# ..                                      ...
# 95                                        2
# 96                                        0
# 97                                        1
# 98                                        1
# 99                                        4
#
#     feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                        1                                0
# 1                                        4                                4
# 2                                        2                                4
# 3                                        3                                3
# 4                                        0                                4
# ..                                     ...                              ...
# 95                                       3                                2
# 96                                       1                                0
# 97                                       0                                3
# 98                                       2                                2
# 99                                       3                                4
#
#     feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  \
# 0                                     0                                 0
# 1                                     3                                 0
# 2                                     2                                 2
# 3                                     4                                 2
# 4                                     4                                 0
# ..                                  ...                               ...
# 95                                    4                                 1
# 96                                    2                                 3
# 97                                    1                                 2
# 98                                    1                                 2
# 99                                    2                                 3
#
#     ...  feature_sprucer_godlier_assembling  \
# 0   ...                                   2
# 1   ...                                   2
# 2   ...                                   2
# 3   ...                                   2
# 4   ...                                   2
# ..  ...                                 ...
# 95  ...                                   2
# 96  ...                                   2
# 97  ...                                   2
# 98  ...                                   2
# 99  ...                                   2
#
#     feature_venturesome_jesting_characterisation  \
# 0                                              2
# 1                                              2
# 2                                              2
# 3                                              2
# 4                                              2
# ..                                           ...
# 95                                             2
# 96                                             2
# 97                                             2
# 98                                             2
# 99                                             2
#
#     feature_unstained_anhedonic_hetty  \
# 0                                   2
# 1                                   2
# 2                                   2
# 3                                   2
# 4                                   2
# ..                                ...
# 95                                  2
# 96                                  2
# 97                                  2
# 98                                  2
# 99                                  2
#
#     feature_vivisectional_latvian_dispensator  \
# 0                                           2
# 1                                           2
# 2                                           2
# 3                                           2
# 4                                           2
# ..                                        ...
# 95                                          2
# 96                                          2
# 97                                          2
# 98                                          2
# 99                                          2
#
#     feature_pantheist_interramal_episcopalianism  \
# 0                                              2
# 1                                              2
# 2                                              2
# 3                                              2
# 4                                              2
# ..                                           ...
# 95                                             2
# 96                                             2
# 97                                             2
# 98                                             2
# 99                                             2
#
#     feature_percurrent_deontic_sectionalisation  \
# 0                                             2
# 1                                             2
# 2                                             2
# 3                                             2
# 4                                             2
# ..                                          ...
# 95                                            2
# 96                                            2
# 97                                            2
# 98                                            2
# 99                                            2
#
#     feature_myalgic_eulogistic_propagation  \
# 0                                        2
# 1                                        2
# 2                                        2
# 3                                        2
# 4                                        2
# ..                                     ...
# 95                                       2
# 96                                       2
# 97                                       2
# 98                                       2
# 99                                       2
#
#     feature_pressor_chiropodial_hypertension  feature_diogenic_wooden_lout  \
# 0                                          2                             2
# 1                                          2                             2
# 2                                          2                             2
# 3                                          2                             2
# 4                                          2                             2
# ..                                       ...                           ...
# 95                                         2                             2
# 96                                         2                             2
# 97                                         2                             2
# 98                                         2                             2
# 99                                         2                             2
#
#     feature_pleuritic_equipotent_loudmouth
# 0                                        2
# 1                                        2
# 2                                        2
# 3                                        2
# 4                                        2
# ..                                     ...
# 95                                       2
# 96                                       2
# 97                                       2
# 98                                       2
# 99                                       2
#
# [100 rows x 2376 columns]

# %%
X=X.reset_index(drop=True)
y=y.reset_index(drop=True)

# %%
X.isnull().values.any()
# Out:
# np.False_

# %%
def  kin_energy(x):
    f=np.unique(x,return_counts=True)
    prob=f[1]/x.shape[0]
    energy=np.sum(prob**2)
    return  energy

# %%
def count_common(x):
    a=np.array(x)
    b=np.where(a==np.min(a))
    v=np.array(b)
    nr_ap=v.shape[1]
    return nr_ap

# %%
def count_least(x):
    a=np.array(x)
    b=np.where(a==np.max(a))
    v=np.array(b)
    nr_ap=v.shape[1]
    return nr_ap

# %%
X["KINETIC_FEAT"]=X.apply(kin_energy,axis=1)

X["max_FEAT"]=X[good_cols].apply(np.max,axis=1)

X["mean_FEAT"]=X[good_cols].apply(np.mean,axis=1)
X["COMMON_COUNT_FEAT"]=X.apply(count_common,axis=1)
X["LEAST_COUNT_FEAT"]=X.apply(count_least,axis=1)

# %%
X.head()
# Out:
#    feature_shaded_hallucinatory_dactylology  \
# 0                                         3
# 1                                         4
# 2                                         2
# 3                                         2
# 4                                         4
#
#    feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                           4                             0
# 1                                           2                             4
# 2                                           4                             0
# 3                                           1                             3
# 4                                           1                             4
#
#    feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                      3                                   3
# 1                                      4                                   0
# 2                                      3                                   0
# 3                                      0                                   3
# 4                                      1                                   0
#
#    feature_symmetrical_spongy_tricentenary  \
# 0                                        1
# 1                                        0
# 2                                        3
# 3                                        0
# 4                                        4
#
#    feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                       1                                0
# 1                                       4                                4
# 2                                       2                                4
# 3                                       3                                3
# 4                                       0                                4
#
#    feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  ...  \
# 0                                    0                                 0  ...
# 1                                    3                                 0  ...
# 2                                    2                                 2  ...
# 3                                    4                                 2  ...
# 4                                    4                                 0  ...
#
#    feature_percurrent_deontic_sectionalisation  \
# 0                                            2
# 1                                            2
# 2                                            2
# 3                                            2
# 4                                            2
#
#    feature_myalgic_eulogistic_propagation  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3                                       2
# 4                                       2
#
#    feature_pressor_chiropodial_hypertension  feature_diogenic_wooden_lout  \
# 0                                         2                             2
# 1                                         2                             2
# 2                                         2                             2
# 3                                         2                             2
# 4                                         2                             2
#
#    feature_pleuritic_equipotent_loudmouth  KINETIC_FEAT  max_FEAT  mean_FEAT  \
# 0                                       2      0.402624         4   1.997054
# 1                                       2      0.390828         4   1.954545
# 2                                       2      0.427758         4   1.962121
# 3                                       2      0.398827         4   2.011785
# 4                                       2      0.378890         4   2.026094
#
#    COMMON_COUNT_FEAT  LEAST_COUNT_FEAT
# 0                182                 1
# 1                400                 1
# 2                167                 1
# 3                203                 1
# 4                221                 1
#
# [5 rows x 2381 columns]

# %%
del train
gc.collect()
# Out:
# 2959

# %%
X["KINETIC_FEAT"]=np.round(X["KINETIC_FEAT"], decimals=2)
X["mean_FEAT"]=np.round(X["mean_FEAT"], decimals=2)

# %%
X["KINETIC_FEAT"]=( X["KINETIC_FEAT"]% 1 * 100).astype(int)
X["mean_FEAT"]=( X["mean_FEAT"]% 1 * 100).astype(int)

# %%
train=X

# %%
train.head()
# Out:
#    feature_shaded_hallucinatory_dactylology  \
# 0                                         3
# 1                                         4
# 2                                         2
# 3                                         2
# 4                                         4
#
#    feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                           4                             0
# 1                                           2                             4
# 2                                           4                             0
# 3                                           1                             3
# 4                                           1                             4
#
#    feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                      3                                   3
# 1                                      4                                   0
# 2                                      3                                   0
# 3                                      0                                   3
# 4                                      1                                   0
#
#    feature_symmetrical_spongy_tricentenary  \
# 0                                        1
# 1                                        0
# 2                                        3
# 3                                        0
# 4                                        4
#
#    feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                       1                                0
# 1                                       4                                4
# 2                                       2                                4
# 3                                       3                                3
# 4                                       0                                4
#
#    feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  ...  \
# 0                                    0                                 0  ...
# 1                                    3                                 0  ...
# 2                                    2                                 2  ...
# 3                                    4                                 2  ...
# 4                                    4                                 0  ...
#
#    feature_percurrent_deontic_sectionalisation  \
# 0                                            2
# 1                                            2
# 2                                            2
# 3                                            2
# 4                                            2
#
#    feature_myalgic_eulogistic_propagation  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3                                       2
# 4                                       2
#
#    feature_pressor_chiropodial_hypertension  feature_diogenic_wooden_lout  \
# 0                                         2                             2
# 1                                         2                             2
# 2                                         2                             2
# 3                                         2                             2
# 4                                         2                             2
#
#    feature_pleuritic_equipotent_loudmouth  KINETIC_FEAT  max_FEAT  mean_FEAT  \
# 0                                       2            40         4          0
# 1                                       2            39         4         95
# 2                                       2            43         4         96
# 3                                       2            40         4          0
# 4                                       2            38         4          2
#
#    COMMON_COUNT_FEAT  LEAST_COUNT_FEAT
# 0                182                 1
# 1                400                 1
# 2                167                 1
# 3                203                 1
# 4                221                 1
#
# [5 rows x 2381 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

# %%
params = {
        "n_estimators": 3_000,
        "learning_rate": 0.05,
        "max_depth": 5,
        #"colsample_bylevel": 0.1,
       
    }
# print out training values 10 times during training run
params["verbose"] = int(params["n_estimators"]/10)
    # max_leaves is left to default value of 31 as it recommended not to make it larger than 64
    
model = CatBoostRegressor(**params)

# %%
model.fit(X_train, y_train)
# Out:
# 0:	learn: 0.2423633	total: 9.98ms	remaining: 29.9s
# 300:	learn: 0.0028510	total: 2.94s	remaining: 26.4s
# 600:	learn: 0.0000401	total: 5.91s	remaining: 23.6s
# 900:	learn: 0.0000009	total: 12.8s	remaining: 29.8s
# 1200:	learn: 0.0000000	total: 18.3s	remaining: 27.4s
# 1500:	learn: 0.0000000	total: 22.9s	remaining: 22.8s
# 1800:	learn: 0.0000000	total: 25.9s	remaining: 17.2s
# 2100:	learn: 0.0000000	total: 32.8s	remaining: 14.1s
# 2400:	learn: 0.0000000	total: 38.9s	remaining: 9.71s
# 2700:	learn: 0.0000000	total: 42.4s	remaining: 4.69s
# 2999:	learn: 0.0000000	total: 49.1s	remaining: 0us

# %%
feature_importances = model.get_feature_importance()

# Get feature names (assuming 'model.feature_names_' contains the feature names)
feature_names = model.feature_names_

# Combine feature names and importance scores into a DataFrame
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances
})

# Sort the DataFrame by importance scores in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
feature_importances
# Out:
# array([3.80522744e-09, 4.67340200e-02, 2.49639225e-19, ...,
#        1.19433755e-01, 1.96913572e-01, 0.00000000e+00])

# %%
feature_importance_df.to_csv('Importance_cat_boost.csv',index=False)

# %%
np.corrcoef(X["feature_elusive_vapoury_accomplice"], X["feature_approbatory_labroid_coracle"])
# Out:
# array([[ 1.        , -0.06994773],
#        [-0.06994773,  1.        ]])

# %%
def gcd(a, b):
    if a == 0 or b == 0:
        return max(a, b)
    return gcd(b, a % b)

# %%
X["GCD_FEAT"]=X.apply(lambda r: gcd(r["feature_elusive_vapoury_accomplice"],r["feature_fortified_repressed_baird"]),axis=1)

# %%
train.head()
# Out:
#    feature_shaded_hallucinatory_dactylology  \
# 0                                         3
# 1                                         4
# 2                                         2
# 3                                         2
# 4                                         4
#
#    feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                           4                             0
# 1                                           2                             4
# 2                                           4                             0
# 3                                           1                             3
# 4                                           1                             4
#
#    feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                      3                                   3
# 1                                      4                                   0
# 2                                      3                                   0
# 3                                      0                                   3
# 4                                      1                                   0
#
#    feature_symmetrical_spongy_tricentenary  \
# 0                                        1
# 1                                        0
# 2                                        3
# 3                                        0
# 4                                        4
#
#    feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                       1                                0
# 1                                       4                                4
# 2                                       2                                4
# 3                                       3                                3
# 4                                       0                                4
#
#    feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  ...  \
# 0                                    0                                 0  ...
# 1                                    3                                 0  ...
# 2                                    2                                 2  ...
# 3                                    4                                 2  ...
# 4                                    4                                 0  ...
#
#    feature_myalgic_eulogistic_propagation  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3                                       2
# 4                                       2
#
#    feature_pressor_chiropodial_hypertension  feature_diogenic_wooden_lout  \
# 0                                         2                             2
# 1                                         2                             2
# 2                                         2                             2
# 3                                         2                             2
# 4                                         2                             2
#
#    feature_pleuritic_equipotent_loudmouth  KINETIC_FEAT  max_FEAT  mean_FEAT  \
# 0                                       2            40         4          0
# 1                                       2            39         4         95
# 2                                       2            43         4         96
# 3                                       2            40         4          0
# 4                                       2            38         4          2
#
#    COMMON_COUNT_FEAT  LEAST_COUNT_FEAT  GCD_FEAT
# 0                182                 1         1
# 1                400                 1         4
# 2                167                 1         3
# 3                203                 1         1
# 4                221                 1         1
#
# [5 rows x 2382 columns]

# %%
def l(a, b):
    if a==0 or b==0:
        return max(a, b)
    else:
        if a!=0 and b!=0:
           lcm=(a*b)/gcd(a, b)
    if a==0 and b==0:
        return 0
    return lcm

# %%
X["LCM_FEAT"]=X.apply(lambda r: l(r["feature_elusive_vapoury_accomplice"], r["feature_limiest_heliolithic_york"]),axis=1)

# %%
train.head(15)
# Out:
#     feature_shaded_hallucinatory_dactylology  \
# 0                                          3
# 1                                          4
# 2                                          2
# 3                                          2
# 4                                          4
# 5                                          4
# 6                                          1
# 7                                          4
# 8                                          3
# 9                                          0
# 10                                         4
# 11                                         0
# 12                                         4
# 13                                         1
# 14                                         1
#
#     feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                            4                             0
# 1                                            2                             4
# 2                                            4                             0
# 3                                            1                             3
# 4                                            1                             4
# 5                                            2                             2
# 6                                            3                             1
# 7                                            4                             4
# 8                                            1                             3
# 9                                            3                             0
# 10                                           0                             0
# 11                                           2                             3
# 12                                           0                             1
# 13                                           1                             1
# 14                                           0                             1
#
#     feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                       3                                   3
# 1                                       4                                   0
# 2                                       3                                   0
# 3                                       0                                   3
# 4                                       1                                   0
# 5                                       3                                   0
# 6                                       2                                   1
# 7                                       4                                   0
# 8                                       0                                   1
# 9                                       3                                   4
# 10                                      4                                   4
# 11                                      1                                   4
# 12                                      0                                   2
# 13                                      2                                   3
# 14                                      0                                   4
#
#     feature_symmetrical_spongy_tricentenary  \
# 0                                         1
# 1                                         0
# 2                                         3
# 3                                         0
# 4                                         4
# 5                                         4
# 6                                         4
# 7                                         0
# 8                                         1
# 9                                         4
# 10                                        0
# 11                                        0
# 12                                        4
# 13                                        0
# 14                                        0
#
#     feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                        1                                0
# 1                                        4                                4
# 2                                        2                                4
# 3                                        3                                3
# 4                                        0                                4
# 5                                        1                                4
# 6                                        1                                1
# 7                                        4                                2
# 8                                        2                                4
# 9                                        1                                1
# 10                                       0                                0
# 11                                       4                                4
# 12                                       2                                4
# 13                                       0                                1
# 14                                       4                                1
#
#     feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  \
# 0                                     0                                 0
# 1                                     3                                 0
# 2                                     2                                 2
# 3                                     4                                 2
# 4                                     4                                 0
# 5                                     1                                 3
# 6                                     3                                 3
# 7                                     3                                 0
# 8                                     1                                 0
# 9                                     0                                 2
# 10                                    2                                 0
# 11                                    0                                 1
# 12                                    3                                 2
# 13                                    4                                 3
# 14                                    2                                 2
#
#     ...  feature_pressor_chiropodial_hypertension  \
# 0   ...                                         2
# 1   ...                                         2
# 2   ...                                         2
# 3   ...                                         2
# 4   ...                                         2
# 5   ...                                         2
# 6   ...                                         2
# 7   ...                                         2
# 8   ...                                         2
# 9   ...                                         2
# 10  ...                                         2
# 11  ...                                         2
# 12  ...                                         2
# 13  ...                                         2
# 14  ...                                         2
#
#     feature_diogenic_wooden_lout  feature_pleuritic_equipotent_loudmouth  \
# 0                              2                                       2
# 1                              2                                       2
# 2                              2                                       2
# 3                              2                                       2
# 4                              2                                       2
# 5                              2                                       2
# 6                              2                                       2
# 7                              2                                       2
# 8                              2                                       2
# 9                              2                                       2
# 10                             2                                       2
# 11                             2                                       2
# 12                             2                                       2
# 13                             2                                       2
# 14                             2                                       2
#
#     KINETIC_FEAT  max_FEAT  mean_FEAT  COMMON_COUNT_FEAT  LEAST_COUNT_FEAT  \
# 0             40         4          0                182                 1
# 1             39         4         95                400                 1
# 2             43         4         96                167                 1
# 3             40         4          0                203                 1
# 4             38         4          2                221                 1
# 5             45         4         85                308                 1
# 6             44         4         16                108                 1
# 7             37         4         94                287                 1
# 8             39         4         84                407                 1
# 9             40         4          6                202                 1
# 10            38         4         77                452                 1
# 11            41         4         90                282                 1
# 12            39         4         86                290                 1
# 13            44         4         98                186                 1
# 14            42         4         98                190                 1
#
#     GCD_FEAT  LCM_FEAT
# 0          1       1.0
# 1          4       4.0
# 2          3       2.0
# 3          1       6.0
# 4          1       2.0
# 5          1       0.0
# 6          4       4.0
# 7          3       3.0
# 8          2       2.0
# 9          3       3.0
# 10         1       4.0
# 11         2       2.0
# 12         1       1.0
# 13         1       3.0
# 14         1       3.0
#
# [15 rows x 2383 columns]

# %%
top_100_feats=list(feature_importance_df["Feature"][:100])

# %%
top_100_feats
# Out:
# ['feature_slimmer_dippiest_reefer',
#  'feature_gargety_burrier_exemplar',
#  'feature_runtier_fetid_supplanter',
#  'feature_whapping_liny_prelate',
#  'feature_accosted_strengthened_displeasure',
#  'feature_reverberatory_minuscule_dhahran',
#  'feature_uncertificated_mat_evisceration',
#  'feature_limiest_heliolithic_york',
#  'feature_dulotic_inspectorial_dartford',
#  'feature_cream_morning_wexford',
#  'feature_emboldened_maledict_doric',
#  'feature_proto_rachidial_heldentenor',
#  'feature_cornier_gular_vespucci',
#  'feature_matchable_feminist_giacomo',
#  'feature_norse_oscine_salome',
#  'feature_calm_genitival_cheville',
#  'feature_undiscoverable_unpastured_bicarbonate',
#  'feature_cankered_nubbliest_foundling',
#  'feature_exoteric_quirky_wolly',
#  'feature_blended_alexic_agent',
#  'feature_microsomal_homeomorphic_alginate',
#  'feature_critical_changeful_porgy',
#  'feature_piliform_ungulate_hood',
#  'feature_located_unifying_truant',
#  'feature_fascistic_necrotic_genip',
#  'feature_untuneable_congealed_matterhorn',
#  'feature_departmental_inimitable_sentencer',
#  'feature_parented_cadenced_dulocracy',
#  'feature_absorbable_hyperalgesic_mode',
#  'feature_pleasurable_facultative_benzol',
#  'feature_realizing_grim_retinue',
#  'feature_majuscule_hibernal_esculent',
#  'feature_damascene_net_database',
#  'feature_surrealism_aerial_verticity',
#  'feature_thrashing_bulky_orchidology',
#  'feature_consolable_unmodulated_indexing',
#  'feature_boozier_multinucleate_muley',
#  'feature_symmetrical_spongy_tricentenary',
#  'feature_unladen_nervine_traversal',
#  'feature_drowsing_perfect_sustainment',
#  'feature_unsigned_canonist_robbie',
#  'feature_photographic_categorized_cowling',
#  'feature_avionic_disjoint_kromesky',
#  'feature_active_yclept_hydrometallurgy',
#  'feature_predestinate_unsurpassed_batten',
#  'feature_unspied_amoroso_miticide',
#  'feature_diversified_feticidal_ousting',
#  'feature_acclamatory_draconian_view',
#  'feature_lowermost_strapped_riksdag',
#  'feature_semestrial_anthropogenic_hostler',
#  'feature_stanchable_hyphenated_lupulin',
#  'feature_columnar_hierurgical_portrayal',
#  'feature_unguerdoned_pursuable_rozzer',
#  'feature_fatalistic_brooding_fitzgerald',
#  'feature_filagree_redundant_underestimation',
#  'feature_supplicatory_ski_broach',
#  'feature_excommunicate_shier_convexity',
#  'feature_execrable_stupid_judicator',
#  'feature_ascidian_unshaping_watchword',
#  'feature_wrongful_oriented_action',
#  'feature_enrolled_breezy_petting',
#  'feature_pleural_interjectional_stilton',
#  'feature_anamorphic_hidden_termagant',
#  'feature_militarized_attenuant_haworth',
#  'feature_eutherian_beastlier_bogong',
#  'feature_unfit_threatful_strontium',
#  'feature_peristomatic_unneighbourly_dogeship',
#  'feature_lymphangial_lapidary_josephine',
#  'feature_voyeuristic_serviceable_isotropy',
#  'feature_inhibitory_embarrassing_nome',
#  'feature_absonant_wintry_hiring',
#  'feature_unimproved_terminist_occupancy',
#  'feature_thallic_else_tirailleur',
#  'feature_giddied_smooth_circumvallation',
#  'feature_disheveled_unmotherly_llandudno',
#  'feature_deflated_patronising_derv',
#  'feature_reconditioned_underglaze_girasol',
#  'feature_circulable_shang_recidivist',
#  'feature_advised_subdural_toadflax',
#  'feature_lamellicorn_undiscomfited_hoofer',
#  'feature_cinematographic_extroverted_hierogram',
#  'feature_realisable_hypogastric_fang',
#  'feature_unformed_bent_smatch',
#  'feature_unilateral_pitchiest_pragmatist',
#  'feature_mildewy_unkind_spree',
#  'feature_bivariate_rabid_fred',
#  'feature_roilier_slippered_patti',
#  'feature_dicastic_unrepelled_propulsion',
#  'feature_choreic_sterilized_lagune',
#  'feature_meridional_synonymic_wyatt',
#  'feature_phagedenic_eccentric_familiar',
#  'feature_beastly_carbonyl_amygdala',
#  'feature_boggy_parthia_styrene',
#  'feature_sluggish_feral_wham',
#  'feature_unspilled_jugate_gliff',
#  'feature_headfirst_rewardable_fahrenheit',
#  'feature_antemeridian_enveloping_duke',
#  'feature_employable_communicable_perpendicularity',
#  'feature_partible_assigned_copycat',
#  'feature_rejective_carinate_ally']

# %%
good_cols=top_100_feats

# %%
good_cols=top_100_feats
X["Sum_FEAT"]=X[good_cols].apply(np.sum,axis=1)

# %%
U=X
X=X[good_cols]
X
# Out:
#     feature_slimmer_dippiest_reefer  feature_gargety_burrier_exemplar  \
# 0                                 4                                 1
# 1                                 0                                 3
# 2                                 3                                 0
# 3                                 0                                 2
# 4                                 2                                 2
# ..                              ...                               ...
# 95                                2                                 3
# 96                                1                                 3
# 97                                0                                 4
# 98                                1                                 4
# 99                                0                                 3
#
#     feature_runtier_fetid_supplanter  feature_whapping_liny_prelate  \
# 0                                  0                              3
# 1                                  4                              3
# 2                                  2                              0
# 3                                  2                              0
# 4                                  1                              2
# ..                               ...                            ...
# 95                                 3                              3
# 96                                 2                              4
# 97                                 0                              4
# 98                                 2                              0
# 99                                 3                              1
#
#     feature_accosted_strengthened_displeasure  \
# 0                                           4
# 1                                           0
# 2                                           3
# 3                                           4
# 4                                           1
# ..                                        ...
# 95                                          1
# 96                                          1
# 97                                          3
# 98                                          3
# 99                                          1
#
#     feature_reverberatory_minuscule_dhahran  \
# 0                                         1
# 1                                         0
# 2                                         1
# 3                                         4
# 4                                         1
# ..                                      ...
# 95                                        2
# 96                                        2
# 97                                        2
# 98                                        1
# 99                                        4
#
#     feature_uncertificated_mat_evisceration  feature_limiest_heliolithic_york  \
# 0                                         2                                 0
# 1                                         0                                 0
# 2                                         1                                 2
# 3                                         2                                 2
# 4                                         2                                 1
# ..                                      ...                               ...
# 95                                        3                                 1
# 96                                        2                                 3
# 97                                        3                                 3
# 98                                        3                                 0
# 99                                        3                                 4
#
#     feature_dulotic_inspectorial_dartford  feature_cream_morning_wexford  ...  \
# 0                                       4                              1  ...
# 1                                       4                              0  ...
# 2                                       2                              4  ...
# 3                                       0                              2  ...
# 4                                       1                              4  ...
# ..                                    ...                            ...  ...
# 95                                      1                              3  ...
# 96                                      2                              2  ...
# 97                                      3                              2  ...
# 98                                      1                              1  ...
# 99                                      4                              1  ...
#
#     feature_phagedenic_eccentric_familiar  feature_beastly_carbonyl_amygdala  \
# 0                                       1                                  1
# 1                                       1                                  2
# 2                                       2                                  1
# 3                                       0                                  3
# 4                                       4                                  3
# ..                                    ...                                ...
# 95                                      2                                  2
# 96                                      0                                  4
# 97                                      1                                  0
# 98                                      1                                  0
# 99                                      4                                  1
#
#     feature_boggy_parthia_styrene  feature_sluggish_feral_wham  \
# 0                               0                            2
# 1                               0                            0
# 2                               2                            1
# 3                               2                            1
# 4                               1                            3
# ..                            ...                          ...
# 95                              1                            4
# 96                              2                            3
# 97                              2                            3
# 98                              2                            1
# 99                              3                            1
#
#     feature_unspilled_jugate_gliff  feature_headfirst_rewardable_fahrenheit  \
# 0                                2                                        1
# 1                                4                                        0
# 2                                2                                        2
# 3                                4                                        4
# 4                                0                                        3
# ..                             ...                                      ...
# 95                               1                                        3
# 96                               2                                        4
# 97                               1                                        4
# 98                               4                                        2
# 99                               2                                        0
#
#     feature_antemeridian_enveloping_duke  \
# 0                                      4
# 1                                      0
# 2                                      4
# 3                                      1
# 4                                      0
# ..                                   ...
# 95                                     1
# 96                                     2
# 97                                     4
# 98                                     0
# 99                                     2
#
#     feature_employable_communicable_perpendicularity  \
# 0                                                  0
# 1                                                  0
# 2                                                  2
# 3                                                  1
# 4                                                  1
# ..                                               ...
# 95                                                 2
# 96                                                 2
# 97                                                 2
# 98                                                 2
# 99                                                 3
#
#     feature_partible_assigned_copycat  feature_rejective_carinate_ally
# 0                                   2                                2
# 1                                   4                                4
# 2                                   0                                2
# 3                                   3                                3
# 4                                   1                                3
# ..                                ...                              ...
# 95                                  0                                0
# 96                                  3                                3
# 97                                  3                                0
# 98                                  4                                0
# 99                                  1                                2
#
# [100 rows x 100 columns]

# %%
X.head()
# Out:
#    feature_slimmer_dippiest_reefer  feature_gargety_burrier_exemplar  \
# 0                                4                                 1
# 1                                0                                 3
# 2                                3                                 0
# 3                                0                                 2
# 4                                2                                 2
#
#    feature_runtier_fetid_supplanter  feature_whapping_liny_prelate  \
# 0                                 0                              3
# 1                                 4                              3
# 2                                 2                              0
# 3                                 2                              0
# 4                                 1                              2
#
#    feature_accosted_strengthened_displeasure  \
# 0                                          4
# 1                                          0
# 2                                          3
# 3                                          4
# 4                                          1
#
#    feature_reverberatory_minuscule_dhahran  \
# 0                                        1
# 1                                        0
# 2                                        1
# 3                                        4
# 4                                        1
#
#    feature_uncertificated_mat_evisceration  feature_limiest_heliolithic_york  \
# 0                                        2                                 0
# 1                                        0                                 0
# 2                                        1                                 2
# 3                                        2                                 2
# 4                                        2                                 1
#
#    feature_dulotic_inspectorial_dartford  feature_cream_morning_wexford  ...  \
# 0                                      4                              1  ...
# 1                                      4                              0  ...
# 2                                      2                              4  ...
# 3                                      0                              2  ...
# 4                                      1                              4  ...
#
#    feature_phagedenic_eccentric_familiar  feature_beastly_carbonyl_amygdala  \
# 0                                      1                                  1
# 1                                      1                                  2
# 2                                      2                                  1
# 3                                      0                                  3
# 4                                      4                                  3
#
#    feature_boggy_parthia_styrene  feature_sluggish_feral_wham  \
# 0                              0                            2
# 1                              0                            0
# 2                              2                            1
# 3                              2                            1
# 4                              1                            3
#
#    feature_unspilled_jugate_gliff  feature_headfirst_rewardable_fahrenheit  \
# 0                               2                                        1
# 1                               4                                        0
# 2                               2                                        2
# 3                               4                                        4
# 4                               0                                        3
#
#    feature_antemeridian_enveloping_duke  \
# 0                                     4
# 1                                     0
# 2                                     4
# 3                                     1
# 4                                     0
#
#    feature_employable_communicable_perpendicularity  \
# 0                                                 0
# 1                                                 0
# 2                                                 2
# 3                                                 1
# 4                                                 1
#
#    feature_partible_assigned_copycat  feature_rejective_carinate_ally
# 0                                  2                                2
# 1                                  4                                4
# 2                                  0                                2
# 3                                  3                                3
# 4                                  1                                3
#
# [5 rows x 100 columns]

# %%
U.head()
# Out:
#    feature_shaded_hallucinatory_dactylology  \
# 0                                         3
# 1                                         4
# 2                                         2
# 3                                         2
# 4                                         4
#
#    feature_itinerant_hexahedral_photoengraver  feature_prudent_pileate_oven  \
# 0                                           4                             0
# 1                                           2                             4
# 2                                           4                             0
# 3                                           1                             3
# 4                                           1                             4
#
#    feature_subalpine_apothegmatical_ajax  feature_pistachio_atypical_malison  \
# 0                                      3                                   3
# 1                                      4                                   0
# 2                                      3                                   0
# 3                                      0                                   3
# 4                                      1                                   0
#
#    feature_symmetrical_spongy_tricentenary  \
# 0                                        1
# 1                                        0
# 2                                        3
# 3                                        0
# 4                                        4
#
#    feature_ungrounded_transpontine_winder  feature_aseptic_eely_hemiplegia  \
# 0                                       1                                0
# 1                                       4                                4
# 2                                       2                                4
# 3                                       3                                3
# 4                                       0                                4
#
#    feature_elemental_easier_alkalinity  feature_cycloid_zymotic_galloway  ...  \
# 0                                    0                                 0  ...
# 1                                    3                                 0  ...
# 2                                    2                                 2  ...
# 3                                    4                                 2  ...
# 4                                    4                                 0  ...
#
#    feature_diogenic_wooden_lout  feature_pleuritic_equipotent_loudmouth  \
# 0                             2                                       2
# 1                             2                                       2
# 2                             2                                       2
# 3                             2                                       2
# 4                             2                                       2
#
#    KINETIC_FEAT  max_FEAT  mean_FEAT  COMMON_COUNT_FEAT  LEAST_COUNT_FEAT  \
# 0            40         4          0                182                 1
# 1            39         4         95                400                 1
# 2            43         4         96                167                 1
# 3            40         4          0                203                 1
# 4            38         4          2                221                 1
#
#    GCD_FEAT  LCM_FEAT  Sum_FEAT
# 0         1       1.0       209
# 1         4       4.0       172
# 2         3       2.0       166
# 3         1       6.0       201
# 4         1       2.0       198
#
# [5 rows x 2384 columns]
